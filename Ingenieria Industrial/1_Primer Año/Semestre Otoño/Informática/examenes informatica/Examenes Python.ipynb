# %%
#Examen de Informática 1º Ingenierías 5-02-2018: EJERCICIO 1
def LeeMatriz():
    m=[]
    for i in range (N):
        a= input('Introduce la fila {} de una matriz {}x{}: '.format(i,N, N))
        a= a.split()
        for j in range (N):
            a[j]=int(a[j])
        m.append(a)
    return m

def ExtraeFila (m, f):
    v = m[f]
    return v

def ExtraeColumna (m, c):
    v=[]
    for i in range (N):
        v.append(m[i][c])
    return v

def ComparaVectores (x, y):
    cuenta = 0
    for i in range (len(x)):
        if x[i]==y[i]:
            cuenta+=1
    return cuenta

def Simetrica (m):
    for i in range (N):
        if ComparaVectores(ExtraeColumna(m,i), ExtraeFila(m,i)) != N:
            a = False
        else:
            a= True
    return a

N=4
m=LeeMatriz()
if Simetrica(m):
    print ('La matriz es simetrica')
else:
    print('La matriz NO es simetrica')

# %%
#Examen de Informática 1º Ingenierías 5-02-2018: EJERCICIO 2
def LeeMatriz ():
    m=[]
    for i in range (N):
        a= input('Introduce una matricula: ')
        a = list (a)
        m.append(a)
    return m

def Extraer (m, f):
    return m[f]

def Valida (v):
    a ='ABCDEFGHIJKLMNÑOPQRSTUVWXYZ'
    b = '0123456789'
    c = True
    for i in range (3):
        if v[i] not in a:
            c=False
    for i in range (3,7):
        if v[i] not in b:
            c=False
    return c

def CreaListado (m):
    r=[]
    cuenta = 0
    for i in range (N):
        x = Extraer(m,i)
        if Valida(x):
            r.append (x)
            cuenta+=1
    return r, cuenta

def Imprime (r, f):
    for i in range (f):
        for j in range (7):
            print (r[i][j], end = ' ')
        print ()
        
N = 6
mOr = LeeMatriz()
mRes, filas = CreaListado(mOr)
print('Las matrículas válidas son:')
Imprime(mRes, filas)

# %%
#Examen de Informática 1º Ingenierías 12-01-2018: EJERCICIO 1
def LeeMatriz ():
    m=[]
    print ('Vamos a introducir una matriz {}x{}'.format (N,N))
    for i in range (N):
        a = input ('Introduce la fila {}: '.format(i))
        a = a.split()
        for j in range (N):
            a[j]=int(a[j])
        m.append (a)
    return m

def ExtraeFila (m, f):
    return m[f]

def Mayor (v):
    a=v[0]
    for i in range (1,N):
        if v[i]>a:
            a=v[i]
    return a

def CreaVector (m):
    v=[]
    for i in range (N):
        v.append(Mayor(ExtraeFila (m, i)))
    return v

def HazMatriz(v):
    m=[]
    a=[]
    for i in range (N):
        x=v[i]
        for j in range (N):
            a.append(x-j)
            if a[j]<0:
                a[j]=0
        m.append(a)
        a=[]
    return m

def EscribeMatriz (m):
    for i in range (N):
        for j in range (N):
            print ('{:4}'.format(m[i][j]), end=' ')
        print ()
        
N=4
m=LeeMatriz()
r=HazMatriz(CreaVector(m))
EscribeMatriz(m)
print ()
EscribeMatriz(r)

# %%
#Examen de Informática 1º Ingenierías 12-01-2018: EJERCICIO 2
def LeeMatriz ():
    m=[]
    print('Vamos a introducir una matriz {}x{}'.format(N, M))
    for i in range (N):
        a=input('Introduce la fila {}: '.format(i))
        a=a.split()
        for j in range (len(a)):
            a[j]=int(a[j])
        m.append(a)
    return m

def SubMatriz (m, f, c):
    r = []
    for i in range (N):
        x= [0]*M
        r.append(x)
    for i in range (f+1):
        for j in range (c+1):
            r[i][j]=m[i][j]
    return r

def SumaMatriz (m):
    suma=0
    for i in range (N):
        for j in range (M):
            suma+=m[i][j]
    return suma

def Sumas (m):
    r=[]
    for i in range (N):
        x=[0]*M
        r.append(x)
    for i in range (N):
        for j in range (M):
            r[i][j]=SumaMatriz(SubMatriz(m,i,j))
    return r

N=4
M=5
m=LeeMatriz()
r=SumaMatriz(Sumas(m))
print ('La suma de los valores de la matriz acumulada es:', r)

# %%
#Examen de Informática 1º Ingenierías 10-01-2017: EJERCICIO 1
def LeeMatriz ():
    m=[]
    print('Vamos a introducir una matriz {}x{}'.format(N, M))
    for i in range (N):
        a=input('Introduce la fila {}: '.format(i))
        a=a.split()
        for j in range (len(a)):
            a[j]=int(a[j])
        m.append(a)
    return m

def DecreceP(m,p,c):
    v=[]
    for i in range (N):
        v.append(m[i][c])
    a=True
    for i in range (1,N):
        if v[i-1]-v[i]!=p:
            a= False
    return a

def ColumnasDecrecenP(m,p):
    t=[]
    r=0
    for i in range (N):
        if DecreceP(m,p,i):
            t.append(i)
            r+=1
    return t,r

def EscribeVector(t,r):
    if r==0:
        print ('Ninguna')
    else:
        for i in range (r):
            print ('{:2}'.format(t[i]), end=' ')
        print()

N=7 
m=LeeMatriz() 

num=int(input('Introduce un número: '))
for i in range (num,0,-1):
    x, y = ColumnasDecrecenP(m,i)
    print ('Decrecen con paso {} las columnas: '.format(i), end='')
    EscribeVector(x, y)
# Out:
# Introduce un número: 4
# Decrecen con paso 4 las columnas:  2
# Decrecen con paso 3 las columnas:  0  5  6
# Decrecen con paso 2 las columnas: Ninguna
# Decrecen con paso 1 las columnas:  1  4

# %%
#Examen de Informática 1º Ingenierías 10-01-2017: EJERCICIO 2
def LeeMatriz():
    m=[]
    print('Introduciremos una matriz {}x{}'.format(N,N))
    for i in range (N):
        a= input('Introduce la fila {}: '.format(i))
        a=a.split()
        m.append(a)
    return m

def ExtraerFila(m,f):
    return m[f]

def ExtraerColumna(m,c):
    v=[]
    for i in range (N):
        v.append(m[i][c])
    return v

def Producto(x,y):
    suma=0
    for i in range (N):
        suma+=int(x[i])*int(y[i])
    return suma

def CreaMatriz(m):
    r=[]
    for i in range (N):
        x=[0]*N
        r.append(x)
    for i in range (N):
        for j in range (N):
            r[i][j]=Producto(ExtraerFila(m,i),ExtraerColumna(m,j))
    return r

def EscribeMatriz(m):
    for i in range (N):
        for j in range (N):
            print('{:4}'.format(m[i][j]), end='')
        print()
        
N=4
m=LeeMatriz()
EscribeMatriz(CreaMatriz(m))
# Out:
# Introduciremos una matriz 4x4
# Introduce la fila 0: 2 1 6 3
# Introduce la fila 1: 8 9 1 6
# Introduce la fila 2: 5 8 1 9
# Introduce la fila 3: 2 7 8 2
#   48  80  43  72
#  105 139 106  99
#   97 148 111  90
#  104 143  43 124

# %%
#Examen de Informática 1º Ingenierías 24-01-2017: EJERCICIO 1
def LeerMatriz ():
    m=[]
    print('Introduciremos una matriz {}x{}'.format(N,N))
    for i in range (N):
        a=input('Introduce la fila {}: '.format(i))
        a=a.split()
        m.append(a)
    for i in range (N):
        for j in range (N):
            m[i][j]=int(m[i][j])
    return m

def MinimoDesdePosicion(m,x):
    a=m[x+1][x+1]
    for i in range (x+1,N):
        for j in range (x+1,N):
            if m[i][j]<a:
                a=m[i][j]
    return a

def RellenarVector(m):
    v=[]
    for i in range(N-1):
        v.append(MinimoDesdePosicion(m,i))
    return v
        
def SonIguales(v):
    a=True
    for i in range (1,len(v)):
        if v[i-1]!=v[i]:
            a=False
    return a

N=5
m=LeerMatriz()
if SonIguales(RellenarVector(m)): 
    print ('Todos los elementos del vector son iguales')
else:
    print('No todos los elementos del vector son iguales')
# Out:
# Introduciremos una matriz 5x5
# Introduce la fila 0: 2 4 -2 8 5
# Introduce la fila 1: 3 6 2 1 4
# Introduce la fila 2: 2 1 4 6 2
# Introduce la fila 3: 8 5 3 4 5
# Introduce la fila 4: 4 2 6 9 7
# [1, 2, 4, 7]
# No todos los elementos delvector son iguales

# %%
#Examen de Informática 1º Ingenierías 24-01-2017: EJERCICIO 2
def LeeMatriz ():
    m=[]
    print('Introduciremos una matriz {}x{}'.format(N,N))
    for i in range (N):
        a=input('Introduce {} carácteres sin espacios: '.format(N))
        a=list(a)
        m.append(a)
    return m

def ExtraerPalabra (m,x):
    return m[x]

def Palindroma (v):
    x=v[::-1]
    a=True
    for i in range (len(v)):
        if x[i]!=v[i]:
            a=False
    return a

def NumeroPalindromas (m):
    cuenta=0
    for i in range (N):
        if Palindroma(ExtraerPalabra (m,i)):
            cuenta+=1
    return cuenta

N=4
m=LeeMatriz ()
a=NumeroPalindromas(m)
print ('Hay {} palabras (filas) palíndromas en la matriz'.format(a))
# Out:
# Introduciremos una matriz 4x4
# Introduce 4 carácteres sin espacios: azza
# Introduce 4 carácteres sin espacios: azza
# Introduce 4 carácteres sin espacios: azza
# Introduce 4 carácteres sin espacios: azza
# Hay 4 palabras (filas) palíndromas en la matriz

# %%
#Examen de Informática 1º Ingenierías 06-06-2016: EJERCICIO 1
def LeeMatriz ():
    m=[]
    print('Vamos a escribir una matriz {}x{}'.format(N,N))
    for i in range (N):
        a=input ('Introduce la fila {}: '.format(i))
        a=a.split()
        m.append(a)
    for i in range (N):
        for j in range (N):
            m[i][j]=int(m[i][j])
    return m

def ExtraerFila(m,f):
    return m[f]

def ExtraerColumna(m,c):
    v=[]
    for i in range (N):
        v.append(m[i][c])
    return v

def ProductoEscalar (x,y):
    suma=0
    for i in range (N):
        suma+= x[i]*y[i]
    return suma

def ProductoDeMatrices (m1,m2):
    r=[]
    for i in range (N):
        r.append([0]*N)
    for i in range (N):
        for j in range (N):
            r[i][j]=ProductoEscalar(ExtraerFila(m1,i),ExtraerColumna(m2,j))
    return r

def EscribeMatriz(m):
    for i in range (N):
        for j in range (N):
            print('{:4}'.format(m[i][j]),end='')
        print()
        
N=2
m1=LeeMatriz()
m2=LeeMatriz()
EscribeMatriz(ProductoDeMatrices(m1,m2))
# Out:
# Vamos a escribir una matriz 2x2
# Introduce la fila 0: 5 6
# Introduce la fila 1: 3 7
# Vamos a escribir una matriz 2x2
# Introduce la fila 0: 3 2
# Introduce la fila 1: 1 5
#   21  40
#   16  41

# %%
#Examen de Informática 1º Ingenierías 06-06-2016: EJERCICIO 
def LeeMatriz():
    m=[]
    print('Vamos a introducir una matriz {}x{} de carácteres'.format(N,N))
    for i in range (N):
        a=list(input('Introduce {} letras sin espacios: '.format(N)))
        m.append(a)
    return m

def LeeVector():
    a=input('Introduce {} numeros entre 1 y {}: '.format(N,N))
    a=a.split()
    for i in range (N):
        a[i]=int(a[i])
    return (a)

def ExtraePalabra(m,f,c):
    v=[]
    for i in range (N):
        v.append(m[f[i]-1][c[i]-1])
    return v

def Palindroma(v):
    a=True
    x=v[::-1]
    for i in range(N):
        if v[i]!=x[i]:
            a=False
    return a

N=4
m=LeeMatriz()
f=LeeVector()
c=LeeVector()
if Palindroma(ExtraePalabra(m,f,c)):
    print('La palabra extraida es palindroma')
else:
    print('La palabra extraida NO es palindroma')
# Out:
# Vamos a introducir una matriz 4x4
# Introduce 4 letras sin espacios: abcf
# Introduce 4 letras sin espacios: ugfz
# Introduce 4 letras sin espacios: advb
# Introduce 4 letras sin espacios: ozig
# Introduce 4 numeros entre 1 y 4: 1 2 4 3
# Introduce 4 numeros entre 1 y 4: 1 4 2 1
# La palabra extraida es palindroma

# %%
#Examen de Informática 1º Ingenierías 24-01-2018: EJERCICIO 1
def LeeMatriz():
    print('Escribe una matriz cuadrada de tamaño {}x{} por filas '.format(n,n))
    m1=[]
    for i in range(n):
        fila=input('Introduce la fila {}: '.format(i)).split()
        for j in range (n):
            fila[j]=int(fila[j])
        m1.append(fila)
    return m1

def LeeVector():
    v=[]
    v=input('Escribe {} números'.format(m)).split()
    for i in range(m):
        v[i]=int(v[i])
    return v

def CoincidenMatrices(a,b):
    num=0
    for i in range(n):
        for j in range(n):
            if a[i][j]==b[i][j]:
                num+=1
    return num

def CoincideT(a,b,t):
    c=True
    if CoincidenMatrices(a,b)!=t:
        c=False
    return c

def PosCoincidentes(a,b,v):
    c=0
    for i in range (m):
        if CoincideT(a,b,v[i]):
            c=i+1
            break
    return c

n=4
m=6
mat1=LeeMatriz()
mat2=LeeMatriz()
vec=LeeVector()
print('En la posición {} está el número de coincidencias'.format(PosCoincidentes(mat1,mat2,vec)))

# %%
#Examen de Informática 1º Ingenierías 24-01-2018: EJERCICIO 2
def LeeMatriz():
    print('Escribe una matriz cuadrada de tamaño {}x{} por filas '.format(N,N))
    m1=[]
    for i in range(N):
        fila=input('Introduce la fila {}: '.format(i)).split()
        for j in range (N):
            fila[j]=int(fila[j])
        m1.append(fila)
    return m1

def ExtraeDiagonalPrincipal(m):
    v=[]
    for i in range (N):
        for j in range (N):
            if i==j:
                v.append(m[i][j])
    return v

def ExtraeDiagonalSecundaria(m):
    v=[]
    for i in range (N):
        v.append(m[i][N-1-i])
    return v

def ComparaVectores (v1,v2):
    par=[]
    impar=[]
    for i in range (N):
        x=v1[i]%v2[i]
        if x%2 ==0:
            par.append(v1[i]//v2[i])
        else:
            impar.append(v1[i]//v2[i])
    return par,impar

def EscribeVector(v,x):
    for i in range (x):
        print('{:4}'.format(v[i]),end='')
    print()
    
N=4
m1=LeeMatriz()
m2=LeeMatriz()
a,b=ComparaVectores(ExtraeDiagonalPrincipal(m1),ExtraeDiagonalSecundaria(m2))
print('El vector PAR es ',EscribeVector(a,len(a)))
print('El vector IMPAR es ',EscribeVector(b,len(b)))

# %%
#Examen de Informática 1º Ingenierías 23-06-2016: EJERCICIO 1
def LeeMatriz():
    m=[]
    print('Introduciermos una matriz {}x{}'.format(N,N))
    for i in range (N):
        a=input('introduce la fila {}: '.format(i)).split()
        for j in range (N):
            a[i]=int(a[i])
        m.append(a)
    return m

def SumaZona(m,x):
    suma=0
    for i in range (x,N-x):
        for j in range (x,N-x):
            if i==x or i==N-x-1 or j==x or j==N-x-1:
                suma+=m[i][j]
    return suma

def VectorSumaZonas(m):
    v=[]
    for i in range ((N+1)//2):
        v.append(SumaZona(m,i))
    return v

def EscribeResultado(v):
    a=0
    for i in range(len(v)):
        if (i+1)%2==0:
            a-=v[i]
        else:
            a+=v[i]
    print ('El resultado es', a)

N=7
m=LeeMatriz()
EscribeResultado(VectorSumaZonas(m))
# Out:
# [80, 51, 32, 2]
# El resultado es 59

# %%
#Examen de Informática 1º Ingenierías 23-06-2016: EJERCICIO 2
def LetrasComunes(a,b):
    c=[]
    x=a[::-1]
    for i in range(N):
        if b[i]==x[i]:
            c.append (b[i])
        else:
            break
    d=len(c)
    return c,d    

def LeeMatriz():
    m=[]
    print('Introduciremos una matriz {}x{}'.format(N,N))
    for i in range (N):
        a=list(input('Introduce {} letras sin espacios: '.format(N)))
        m.append(a)
    return m

def ExtraeFila(m,f):
    return m[f]

def Coincidencias(m):
    print('Se mostrarán en pantalla las siguientes coincidencias:')
    for i in range (N-1):
        x,y=LetrasComunes(ExtraeFila(m,i),ExtraeFila(m,i+1))
        for j in range (y):
            print(x[j], end='')
        print()

N=7
r=LeeMatriz()
Coincidencias(r)
# Out:
# (['r', 'g', 'f'], 3)
# Se mostrarán en pantalla las siguientes coincidencias:
# rgf
# er
# ett
#
# lo
